# %% [markdown]
# # Data Import SQL
#
# Converting all the empty strings in the csv file into NULL so that we can import it to the MySQL Workbench.
#
# - From `.xlsx` to `.csv`: https://cloudconvert.com/xlsx-to-csv

# %%
import pandas as pd

# %% [markdown]
# ## Converting Vaccination Dataset

# %%
df = pd.read_csv("CovidVaccEmpty.csv")
df = df.fillna("\\N")
df.to_csv("CovidVacc.csv", index=False)

# %%
df.to_csv("CovidVacc.csv", index=False)

# %% [markdown]
# ## Converting Deaths Dataset

# %%
df = pd.read_csv("CovidDeathsEmpty.csv")
df = df.fillna("\\N")
df.to_csv("CovidDeaths.csv", index=False)

# %%
df
# Out:
#       iso_code continent     location       date total_cases new_cases  \
# 0          AFG      Asia  Afghanistan  2/24/2020         1.0       1.0
# 1          AFG      Asia  Afghanistan  2/25/2020         1.0       0.0
# 2          AFG      Asia  Afghanistan  2/26/2020         1.0       0.0
# 3          AFG      Asia  Afghanistan  2/27/2020         1.0       0.0
# 4          AFG      Asia  Afghanistan  2/28/2020         1.0       0.0
# ...        ...       ...          ...        ...         ...       ...
# 85166      ZWE    Africa     Zimbabwe  4/26/2021     38102.0      16.0
# 85167      ZWE    Africa     Zimbabwe  4/27/2021     38164.0      62.0
# 85168      ZWE    Africa     Zimbabwe  4/28/2021     38191.0      27.0
# 85169      ZWE    Africa     Zimbabwe  4/29/2021     38235.0      44.0
# 85170      ZWE    Africa     Zimbabwe  4/30/2021     38257.0      22.0
#
#       new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 0                     \N           \N         \N                  \N  ...
# 1                     \N           \N         \N                  \N  ...
# 2                     \N           \N         \N                  \N  ...
# 3                     \N           \N         \N                  \N  ...
# 4                     \N           \N         \N                  \N  ...
# ...                  ...          ...        ...                 ...  ...
# 85166             34.714       1560.0        3.0                 1.0  ...
# 85167             41.286       1565.0        5.0               1.571  ...
# 85168             30.143       1565.0        0.0               1.429  ...
# 85169               31.0       1567.0        2.0               1.714  ...
# 85170             30.286       1567.0        0.0               1.571  ...
#
#       gdp_per_capita extreme_poverty cardiovasc_death_rate  \
# 0           1803.987              \N               597.029
# 1           1803.987              \N               597.029
# 2           1803.987              \N               597.029
# 3           1803.987              \N               597.029
# 4           1803.987              \N               597.029
# ...              ...             ...                   ...
# 85166       1899.775            21.4               307.846
# 85167       1899.775            21.4               307.846
# 85168       1899.775            21.4               307.846
# 85169       1899.775            21.4               307.846
# 85170       1899.775            21.4               307.846
#
#       diabetes_prevalence female_smokers male_smokers handwashing_facilities  \
# 0                    9.59             \N           \N                 37.746
# 1                    9.59             \N           \N                 37.746
# 2                    9.59             \N           \N                 37.746
# 3                    9.59             \N           \N                 37.746
# 4                    9.59             \N           \N                 37.746
# ...                   ...            ...          ...                    ...
# 85166                1.82            1.6         30.7                 36.791
# 85167                1.82            1.6         30.7                 36.791
# 85168                1.82            1.6         30.7                 36.791
# 85169                1.82            1.6         30.7                 36.791
# 85170                1.82            1.6         30.7                 36.791
#
#       hospital_beds_per_thousand life_expectancy human_development_index
# 0                            0.5           64.83                   0.511
# 1                            0.5           64.83                   0.511
# 2                            0.5           64.83                   0.511
# 3                            0.5           64.83                   0.511
# 4                            0.5           64.83                   0.511
# ...                          ...             ...                     ...
# 85166                        1.7           61.49                   0.571
# 85167                        1.7           61.49                   0.571
# 85168                        1.7           61.49                   0.571
# 85169                        1.7           61.49                   0.571
# 85170                        1.7           61.49                   0.571
#
# [85171 rows x 59 columns]
